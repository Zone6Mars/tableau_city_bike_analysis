# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
jan2021 = "Data/2021/JC-202101-citibike-tripdata.csv"
feb2021 = "Data/2021/JC-202102-citibike-tripdata.csv"
mar2021 = "Data/2021/JC-202103-citibike-tripdata.csv"
apr2021 = "Data/2021/JC-202104-citibike-tripdata.csv"
may2021 = "Data/2021/JC-202105-citibike-tripdata.csv"
jun2021 = "Data/2021/JC-202106-citibike-tripdata.csv"
jul2021 = "Data/2021/JC-202107-citibike-tripdata.csv"
aug2021 = "Data/2021/JC-202108-citibike-tripdata.csv"
sep2021 = "Data/2021/JC-202109-citibike-tripdata.csv"
oct2021 = "Data/2021/JC-202110-citibike-tripdata.csv"

# %%
jan2021_df = pd.read_csv(jan2021)
feb2021_df = pd.read_csv(feb2021)
mar2021_df = pd.read_csv(mar2021)
apr2021_df = pd.read_csv(apr2021)
may2021_df = pd.read_csv(may2021)
jun2021_df = pd.read_csv(jun2021)
jul2021_df = pd.read_csv(jul2021)
aug2021_df = pd.read_csv(aug2021)
sep2021_df = pd.read_csv(sep2021)
oct2021_df = pd.read_csv(oct2021)

# %%
jan2021_df.count()
# Out:
# tripduration               11624
# starttime                  11624
# stoptime                   11624
# start station id           11624
# start station name         11624
# start station latitude     11624
# start station longitude    11624
# end station id             11624
# end station name           11624
# end station latitude       11624
# end station longitude      11624
# bikeid                     11624
# usertype                   11624
# birth year                 11624
# gender                     11624
# dtype: int64

# %%
# Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
jan2021_df["starttime"] = pd.to_datetime(jan2021_df["starttime"])
jan2021_df["stoptime"] = pd.to_datetime(jan2021_df["stoptime"])

# %%
Clean_jan2021_df = jan2021_df.drop(columns=['birth year', 'gender', 'bikeid'])

# %%
Clean_jan2021_df
# Out:
#        tripduration               starttime                stoptime  \
# 0               266 2021-01-01 00:03:35.510 2021-01-01 00:08:01.777
# 1              1543 2021-01-01 00:23:32.925 2021-01-01 00:49:16.083
# 2              1461 2021-01-01 00:23:50.794 2021-01-01 00:48:12.566
# 3               793 2021-01-01 00:31:09.077 2021-01-01 00:44:22.943
# 4               596 2021-01-01 00:35:52.190 2021-01-01 00:45:48.774
# ...             ...                     ...                     ...
# 11619          2476 2021-01-31 20:16:05.470 2021-01-31 20:57:22.011
# 11620           147 2021-01-31 21:05:05.209 2021-01-31 21:07:32.866
# 11621           660 2021-01-31 21:06:23.588 2021-01-31 21:17:23.842
# 11622           384 2021-01-31 21:16:37.822 2021-01-31 21:23:02.124
# 11623           356 2021-01-31 23:24:50.881 2021-01-31 23:30:47.303
#
#        start station id start station name  start station latitude  \
# 0                  3273       Manila & 1st               40.721651
# 1                  3681           Grand St               40.715178
# 2                  3681           Grand St               40.715178
# 3                  3185          City Hall               40.717732
# 4                  3639         Harborside               40.719252
# ...                 ...                ...                     ...
# 11619              3187          Warren St               40.721124
# 11620              3186      Grove St PATH               40.719586
# 11621              3211         Newark Ave               40.721525
# 11622              3205  JC Medical Center               40.716540
# 11623              3639         Harborside               40.719252
#
#        start station longitude  end station id  end station name  \
# 0                   -74.042884            3209      Brunswick St
# 1                   -74.037683            3213    Van Vorst Park
# 2                   -74.037683            3213    Van Vorst Park
# 3                   -74.043845            3199      Newport Pkwy
# 4                   -74.034234            3209      Brunswick St
# ...                        ...             ...               ...
# 11619               -74.038051            3483     Montgomery St
# 11620               -74.043117            3187         Warren St
# 11621               -74.046305            3276  Marin Light Rail
# 11622               -74.049638            3268    Lafayette Park
# 11623               -74.034234            3186     Grove St PATH
#
#        end station latitude  end station longitude    usertype
# 0                 40.724176             -74.050656  Subscriber
# 1                 40.718489             -74.047727    Customer
# 2                 40.718489             -74.047727    Customer
# 3                 40.728745             -74.032108    Customer
# 4                 40.724176             -74.050656    Customer
# ...                     ...                    ...         ...
# 11619             40.719420             -74.050990  Subscriber
# 11620             40.721124             -74.038051  Subscriber
# 11621             40.714584             -74.042817  Subscriber
# 11622             40.713464             -74.062859  Subscriber
# 11623             40.719586             -74.043117  Subscriber
#
# [11624 rows x 12 columns]

# %%
Clean_jan2021_df['usertype'].replace('Subscriber','member',inplace = True)

# %%
Clean_jan2021_df['usertype'].replace('Customer','casual',inplace = True)

# %%
Clean_jan2021_df.head()
# Out:
#    tripduration               starttime                stoptime  \
# 0           266 2021-01-01 00:03:35.510 2021-01-01 00:08:01.777
# 1          1543 2021-01-01 00:23:32.925 2021-01-01 00:49:16.083
# 2          1461 2021-01-01 00:23:50.794 2021-01-01 00:48:12.566
# 3           793 2021-01-01 00:31:09.077 2021-01-01 00:44:22.943
# 4           596 2021-01-01 00:35:52.190 2021-01-01 00:45:48.774
#
#    start station id start station name  start station latitude  \
# 0              3273       Manila & 1st               40.721651
# 1              3681           Grand St               40.715178
# 2              3681           Grand St               40.715178
# 3              3185          City Hall               40.717732
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.042884            3209     Brunswick St
# 1               -74.037683            3213   Van Vorst Park
# 2               -74.037683            3213   Van Vorst Park
# 3               -74.043845            3199     Newport Pkwy
# 4               -74.034234            3209     Brunswick St
#
#    end station latitude  end station longitude usertype
# 0             40.724176             -74.050656   member
# 1             40.718489             -74.047727   casual
# 2             40.718489             -74.047727   casual
# 3             40.728745             -74.032108   casual
# 4             40.724176             -74.050656   casual

# %%
Clean_jan2021_df.count()
# Out:
# tripduration               11624
# starttime                  11624
# stoptime                   11624
# start station id           11624
# start station name         11624
# start station latitude     11624
# start station longitude    11624
# end station id             11624
# end station name           11624
# end station latitude       11624
# end station longitude      11624
# usertype                   11624
# dtype: int64

# %%
feb2021_df.count()
# Out:
# ride_id               4881
# rideable_type         4881
# started_at            4881
# ended_at              4881
# start_station_name    4881
# start_station_id      4881
# end_station_name      4813
# end_station_id        4813
# start_lat             4881
# start_lng             4881
# end_lat               4813
# end_lng               4813
# member_casual         4881
# dtype: int64

# %%
feb2021_df
# Out:
#                ride_id rideable_type           started_at  \
# 0     121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28
# 1     FD73FB85F008349D   docked_bike  2021-02-27 16:34:05
# 2     39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04
# 3     A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50
# 4     75CC76EB9543764A   docked_bike  2021-02-24 20:44:16
# ...                ...           ...                  ...
# 4876  3F8FD9A051C0E3DA   docked_bike  2021-02-24 18:05:45
# 4877  B91F3593C0C06D04   docked_bike  2021-02-22 18:22:04
# 4878  A790954A017D07CB   docked_bike  2021-02-13 12:21:49
# 4879  42B1932D06CEE034   docked_bike  2021-02-25 11:20:29
# 4880  F71732ECE7CD02CF   docked_bike  2021-02-19 13:59:22
#
#                  ended_at          start_station_name start_station_id  \
# 0     2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1     2021-02-27 16:56:40                Newport Pkwy            JC008
# 2     2021-02-26 23:22:25              Journal Square            JC103
# 3     2021-02-24 17:16:09  Hoboken Ave at Monmouth St            JC105
# 4     2021-02-24 20:44:46  Hoboken Ave at Monmouth St            JC105
# ...                   ...                         ...              ...
# 4876  2021-02-24 18:12:27              Columbus Drive            JC014
# 4877  2021-02-22 18:28:45              Columbus Drive            JC014
# 4878  2021-02-13 12:27:51              Columbus Drive            JC014
# 4879  2021-02-25 11:25:23              Columbus Drive            JC014
# 4880  2021-02-19 14:05:47              Columbus Drive            JC014
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0                Christ Hospital          JC034  40.735208 -74.046964
# 1               Marin Light Rail          JC013  40.728744 -74.032108
# 2          Baldwin at Montgomery          JC020  40.733670 -74.062500
# 3     Hoboken Ave at Monmouth St          JC105  40.735208 -74.046963
# 4     Hoboken Ave at Monmouth St          JC105  40.735208 -74.046963
# ...                          ...            ...        ...        ...
# 4876                Newport Pkwy          JC008  40.718355 -74.038914
# 4877                Newport Pkwy          JC008  40.718355 -74.038914
# 4878                Newport Pkwy          JC008  40.718355 -74.038914
# 4879                Morris Canal          JC072  40.718355 -74.038914
# 4880                Newport Pkwy          JC008  40.718355 -74.038914
#
#         end_lat    end_lng member_casual
# 0     40.734786 -74.050444        member
# 1     40.714584 -74.042817        member
# 2     40.723659 -74.064194        member
# 3     40.735208 -74.046964        casual
# 4     40.735208 -74.046964        member
# ...         ...        ...           ...
# 4876  40.728745 -74.032108        member
# 4877  40.728745 -74.032108        member
# 4878  40.728745 -74.032108        member
# 4879  40.712419 -74.038526        member
# 4880  40.728745 -74.032108        member
#
# [4881 rows x 13 columns]

# %%
oct2021_df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      0FA0B0B972A68AAB  classic_bike  2021-10-19 06:08:46
# 1      0702BED6EB379838  classic_bike  2021-10-16 12:08:29
# 2      A8810ECCC69E2866  classic_bike  2021-10-29 12:29:49
# 3      C9A0FF2B82237FFA  classic_bike  2021-10-08 12:36:21
# 4      7DFDEB8EF4CAB15C  classic_bike  2021-10-14 06:54:51
# ...                 ...           ...                  ...
# 88757  2B1145DCE1C12234  classic_bike  2021-10-22 21:33:14
# 88758  9332D910D93C0961  classic_bike  2021-10-16 14:30:26
# 88759  9BD55309848AD745  classic_bike  2021-10-17 02:11:58
# 88760  263F1EE58709CB6D  classic_bike  2021-10-07 20:38:47
# 88761  2D38261C42BE80F3  classic_bike  2021-10-23 23:48:08
#
#                   ended_at start_station_name start_station_id  \
# 0      2021-10-19 06:11:26       Glenwood Ave            JC094
# 1      2021-10-16 12:13:29       Glenwood Ave            JC094
# 2      2021-10-29 12:34:49       Glenwood Ave            JC094
# 3      2021-10-08 12:40:55       Glenwood Ave            JC094
# 4      2021-10-14 07:01:14       Glenwood Ave            JC094
# ...                    ...                ...              ...
# 88757  2021-10-22 21:56:13  Clinton St & 7 St            HB303
# 88758  2021-10-16 14:35:43  Clinton St & 7 St            HB303
# 88759  2021-10-17 02:18:26  Clinton St & 7 St            HB303
# 88760  2021-10-07 20:44:49  Clinton St & 7 St            HB303
# 88761  2021-10-23 23:55:02  Clinton St & 7 St            HB303
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0                               Sip Ave          JC056  40.727551 -74.071061
# 1                               Sip Ave          JC056  40.727551 -74.071061
# 2                               Sip Ave          JC056  40.727551 -74.071061
# 3                               Sip Ave          JC056  40.727551 -74.071061
# 4                               Sip Ave          JC056  40.727551 -74.071061
# ...                                 ...            ...        ...        ...
# 88757  City Hall - Washington St & 1 St          HB105  40.745420 -74.033320
# 88758  City Hall - Washington St & 1 St          HB105  40.745420 -74.033320
# 88759                  Grand St & 14 St          HB506  40.745420 -74.033320
# 88760                  Grand St & 14 St          HB506  40.745420 -74.033320
# 88761                  Grand St & 14 St          HB506  40.745420 -74.033320
#
#          end_lat    end_lng member_casual
# 0      40.730897 -74.063913        member
# 1      40.730897 -74.063913        member
# 2      40.730897 -74.063913        member
# 3      40.730897 -74.063913        member
# 4      40.730897 -74.063913        casual
# ...          ...        ...           ...
# 88757  40.737360 -74.030970        casual
# 88758  40.737360 -74.030970        casual
# 88759  40.754090 -74.031600        casual
# 88760  40.754090 -74.031600        casual
# 88761  40.754090 -74.031600        casual
#
# [88762 rows x 13 columns]

# %%
febthruoct_df = feb2021_df.append([mar2021_df, apr2021_df, may2021_df, jun2021_df, jul2021_df, aug2021_df, sep2021_df, oct2021_df], ignore_index=True)
febthruoct_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28  2021-02-03 23:18:28
# 1  FD73FB85F008349D   docked_bike  2021-02-27 16:34:05  2021-02-27 16:56:40
# 2  39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04  2021-02-26 23:22:25
# 3  A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50  2021-02-24 17:16:09
# 4  75CC76EB9543764A   docked_bike  2021-02-24 20:44:16  2021-02-24 20:44:46
#
#            start_station_name start_station_id            end_station_name  \
# 0  Hoboken Ave at Monmouth St            JC105             Christ Hospital
# 1                Newport Pkwy            JC008            Marin Light Rail
# 2              Journal Square            JC103       Baldwin at Montgomery
# 3  Hoboken Ave at Monmouth St            JC105  Hoboken Ave at Monmouth St
# 4  Hoboken Ave at Monmouth St            JC105  Hoboken Ave at Monmouth St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# 0          JC034  40.735208 -74.046964  40.734786 -74.050444        member
# 1          JC013  40.728744 -74.032108  40.714584 -74.042817        member
# 2          JC020  40.733670 -74.062500  40.723659 -74.064194        member
# 3          JC105  40.735208 -74.046963  40.735208 -74.046964        casual
# 4          JC105  40.735208 -74.046963  40.735208 -74.046964        member

# %%
febthruoct_df.count()
# Out:
# ride_id               524650
# rideable_type         524650
# started_at            524650
# ended_at              524650
# start_station_name    524650
# start_station_id      524650
# end_station_name      522045
# end_station_id        522045
# start_lat             524650
# start_lng             524650
# end_lat               522844
# end_lng               522844
# member_casual         524650
# dtype: int64

# %%
# Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
febthruoct_df["started_at"] = pd.to_datetime(febthruoct_df["started_at"])
febthruoct_df["ended_at"] = pd.to_datetime(febthruoct_df["ended_at"])

# %%
Clean_jan2021_df.count()
# Out:
# tripduration               11624
# starttime                  11624
# stoptime                   11624
# start station id           11624
# start station name         11624
# start station latitude     11624
# start station longitude    11624
# end station id             11624
# end station name           11624
# end station latitude       11624
# end station longitude      11624
# usertype                   11624
# dtype: int64

# %%
febthruoct_df["tripduration"] = febthruoct_df["ended_at"]- febthruoct_df["started_at"]

# %%
febthruoct_df["tripduration"] = febthruoct_df["tripduration"]/np.timedelta64(1,'s')

# %%
febthruoct_df_reorder = febthruoct_df[['ride_id','rideable_type','tripduration','started_at','ended_at','start_station_id','start_station_name','start_lat','start_lng','end_station_id','end_station_name','end_lat','end_lng','member_casual']]

# %%
febthruoct_df_reorder.count()
# Out:
# ride_id               524650
# rideable_type         524650
# tripduration          524650
# started_at            524650
# ended_at              524650
# start_station_id      524650
# start_station_name    524650
# start_lat             524650
# start_lng             524650
# end_station_id        522045
# end_station_name      522045
# end_lat               522844
# end_lng               522844
# member_casual         524650
# dtype: int64

# %%
febthruoct_df_reorder_rename = febthruoct_df_reorder.rename(columns={"started_at": "starttime",
                                            "ended_at": "stoptime",
                                            "start_station_id": "start station id",
                                            "start_station_name": "start station name",
                                            "start_lat": "start station latitude",
                                            "start_lng": "start station longitude",
                                            "end_station_id": "end station id",
                                            "end_station_name": "end station name",
                                            "end_lat": "end station latitude",
                                            "end_lng": "end station longitude",
                                            "member_casual": "usertype",
                                           })
febthruoct_df_reorder_rename
# Out:
#                  ride_id rideable_type  tripduration           starttime  \
# 0       121DD7DD23CB1335   docked_bike         420.0 2021-02-03 23:11:28
# 1       FD73FB85F008349D   docked_bike        1355.0 2021-02-27 16:34:05
# 2       39F9E6663CB5FDF6   docked_bike         381.0 2021-02-26 23:16:04
# 3       A64745CB0792EC6F   docked_bike        1459.0 2021-02-24 16:51:50
# 4       75CC76EB9543764A   docked_bike          30.0 2021-02-24 20:44:16
# ...                  ...           ...           ...                 ...
# 524645  2B1145DCE1C12234  classic_bike        1379.0 2021-10-22 21:33:14
# 524646  9332D910D93C0961  classic_bike         317.0 2021-10-16 14:30:26
# 524647  9BD55309848AD745  classic_bike         388.0 2021-10-17 02:11:58
# 524648  263F1EE58709CB6D  classic_bike         362.0 2021-10-07 20:38:47
# 524649  2D38261C42BE80F3  classic_bike         414.0 2021-10-23 23:48:08
#
#                   stoptime start station id          start station name  \
# 0      2021-02-03 23:18:28            JC105  Hoboken Ave at Monmouth St
# 1      2021-02-27 16:56:40            JC008                Newport Pkwy
# 2      2021-02-26 23:22:25            JC103              Journal Square
# 3      2021-02-24 17:16:09            JC105  Hoboken Ave at Monmouth St
# 4      2021-02-24 20:44:46            JC105  Hoboken Ave at Monmouth St
# ...                    ...              ...                         ...
# 524645 2021-10-22 21:56:13            HB303           Clinton St & 7 St
# 524646 2021-10-16 14:35:43            HB303           Clinton St & 7 St
# 524647 2021-10-17 02:18:26            HB303           Clinton St & 7 St
# 524648 2021-10-07 20:44:49            HB303           Clinton St & 7 St
# 524649 2021-10-23 23:55:02            HB303           Clinton St & 7 St
#
#         start station latitude  start station longitude end station id  \
# 0                    40.735208               -74.046964          JC034
# 1                    40.728744               -74.032108          JC013
# 2                    40.733670               -74.062500          JC020
# 3                    40.735208               -74.046963          JC105
# 4                    40.735208               -74.046963          JC105
# ...                        ...                      ...            ...
# 524645               40.745420               -74.033320          HB105
# 524646               40.745420               -74.033320          HB105
# 524647               40.745420               -74.033320          HB506
# 524648               40.745420               -74.033320          HB506
# 524649               40.745420               -74.033320          HB506
#
#                         end station name  end station latitude  \
# 0                        Christ Hospital             40.734786
# 1                       Marin Light Rail             40.714584
# 2                  Baldwin at Montgomery             40.723659
# 3             Hoboken Ave at Monmouth St             40.735208
# 4             Hoboken Ave at Monmouth St             40.735208
# ...                                  ...                   ...
# 524645  City Hall - Washington St & 1 St             40.737360
# 524646  City Hall - Washington St & 1 St             40.737360
# 524647                  Grand St & 14 St             40.754090
# 524648                  Grand St & 14 St             40.754090
# 524649                  Grand St & 14 St             40.754090
#
#         end station longitude usertype
# 0                  -74.050444   member
# 1                  -74.042817   member
# 2                  -74.064194   member
# 3                  -74.046964   casual
# 4                  -74.046964   member
# ...                       ...      ...
# 524645             -74.030970   casual
# 524646             -74.030970   casual
# 524647             -74.031600   casual
# 524648             -74.031600   casual
# 524649             -74.031600   casual
#
# [524650 rows x 14 columns]

# %%
febthruoct_df_reorder_rename['tripduration'].max()
# Out:
# 9020291.0

# %%
Clean_febthruoct_df_reorder_rename = febthruoct_df_reorder_rename.drop(columns=['ride_id', 'rideable_type'])

# %%
Clean_febthruoct_df_reorder_rename.count()
# Out:
# tripduration               524650
# starttime                  524650
# stoptime                   524650
# start station id           524650
# start station name         524650
# start station latitude     524650
# start station longitude    524650
# end station id             522045
# end station name           522045
# end station latitude       522844
# end station longitude      522844
# usertype                   524650
# dtype: int64

# %%
Clean_jan2021_df.count()
# Out:
# tripduration               11624
# starttime                  11624
# stoptime                   11624
# start station id           11624
# start station name         11624
# start station latitude     11624
# start station longitude    11624
# end station id             11624
# end station name           11624
# end station latitude       11624
# end station longitude      11624
# usertype                   11624
# dtype: int64

# %%
Clean_febthruoct_df_reorder_rename.head()
# Out:
#    tripduration           starttime            stoptime start station id  \
# 0         420.0 2021-02-03 23:11:28 2021-02-03 23:18:28            JC105
# 1        1355.0 2021-02-27 16:34:05 2021-02-27 16:56:40            JC008
# 2         381.0 2021-02-26 23:16:04 2021-02-26 23:22:25            JC103
# 3        1459.0 2021-02-24 16:51:50 2021-02-24 17:16:09            JC105
# 4          30.0 2021-02-24 20:44:16 2021-02-24 20:44:46            JC105
#
#            start station name  start station latitude  \
# 0  Hoboken Ave at Monmouth St               40.735208
# 1                Newport Pkwy               40.728744
# 2              Journal Square               40.733670
# 3  Hoboken Ave at Monmouth St               40.735208
# 4  Hoboken Ave at Monmouth St               40.735208
#
#    start station longitude end station id            end station name  \
# 0               -74.046964          JC034             Christ Hospital
# 1               -74.032108          JC013            Marin Light Rail
# 2               -74.062500          JC020       Baldwin at Montgomery
# 3               -74.046963          JC105  Hoboken Ave at Monmouth St
# 4               -74.046963          JC105  Hoboken Ave at Monmouth St
#
#    end station latitude  end station longitude usertype
# 0             40.734786             -74.050444   member
# 1             40.714584             -74.042817   member
# 2             40.723659             -74.064194   member
# 3             40.735208             -74.046964   casual
# 4             40.735208             -74.046964   member

# %%
Clean_BikeData_2021_df = Clean_jan2021_df.append([Clean_febthruoct_df_reorder_rename])

# %%
Clean_BikeData_2021_df.head()
# Out:
#    tripduration               starttime                stoptime  \
# 0         266.0 2021-01-01 00:03:35.510 2021-01-01 00:08:01.777
# 1        1543.0 2021-01-01 00:23:32.925 2021-01-01 00:49:16.083
# 2        1461.0 2021-01-01 00:23:50.794 2021-01-01 00:48:12.566
# 3         793.0 2021-01-01 00:31:09.077 2021-01-01 00:44:22.943
# 4         596.0 2021-01-01 00:35:52.190 2021-01-01 00:45:48.774
#
#   start station id start station name  start station latitude  \
# 0             3273       Manila & 1st               40.721651
# 1             3681           Grand St               40.715178
# 2             3681           Grand St               40.715178
# 3             3185          City Hall               40.717732
# 4             3639         Harborside               40.719252
#
#    start station longitude end station id end station name  \
# 0               -74.042884           3209     Brunswick St
# 1               -74.037683           3213   Van Vorst Park
# 2               -74.037683           3213   Van Vorst Park
# 3               -74.043845           3199     Newport Pkwy
# 4               -74.034234           3209     Brunswick St
#
#    end station latitude  end station longitude usertype
# 0             40.724176             -74.050656   member
# 1             40.718489             -74.047727   casual
# 2             40.718489             -74.047727   casual
# 3             40.728745             -74.032108   casual
# 4             40.724176             -74.050656   casual

# %%
Clean_BikeData_2021_df.count()
# Out:
# tripduration               536274
# starttime                  536274
# stoptime                   536274
# start station id           536274
# start station name         536274
# start station latitude     536274
# start station longitude    536274
# end station id             533669
# end station name           533669
# end station latitude       534468
# end station longitude      534468
# usertype                   536274
# dtype: int64

# %%
Clean_BikeData_2021_df.to_csv("Source/Clean_BikeData_2021_df.csv", index=False, header=True)
